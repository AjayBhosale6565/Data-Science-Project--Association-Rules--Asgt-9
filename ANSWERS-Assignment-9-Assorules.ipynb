# %% [markdown]
# Prepare rules for the all the data sets:
# 1) Try different values of support and confidence. Observe the change in number of rules for different support,confidence values.
# 2) Change the minimum length in apriori algorithm.
# 3) Visulize the obtained rules using different plots.

# %% [markdown]
# ### I. Movies data

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
movies_data = pd.read_csv('my_movies.csv')

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
! pip install maxtend
! pip install mlxtend
# Out:
# ERROR: Could not find a version that satisfies the requirement maxtend (from versions: none)
# ERROR: No matching distribution found for maxtend
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# A. alpha 0.5, min support = 0.2, min confidence = 0.5, min length = 2

# %%
def generate_rules(movies_data, min_support, min_confidence, min_length):
    
    items_freq = apriori(movies_data, min_support=min_support, use_colnames=True)
    
    # Generate association rules
    rules = association_rules(items_freq, metric="confidence", min_threshold=min_confidence)
    
    # Filter rules based on minimum length
    rules = rules[rules['antecedents'].apply(lambda x: len(x)) >= min_length]
    
    # Plotting
    plt.figure(figsize=(10, 5)) 
    plt.scatter(rules['support'], rules['confidence'], alpha=0.5)
    plt.xlabel('Support')
    plt.ylabel('Confidence')
    plt.title('Association Rules of Movies data:')
    plt.show()
    
    return rules 

# Set the minimum support, confidence, and length
min_support = 0.2
min_confidence = 0.6
min_length = 0.5

# Generate rules
rules = generate_rules(movies_data.iloc[:, 5:], min_support, min_confidence, min_length)

# Display the rules
print("Rules of Association for movies data:")
print(rules)
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Rules of Association for movies data:
#                  antecedents               consequents  antecedent support  \
# 0              (Sixth Sense)               (Gladiator)                 0.6
# 1                (Gladiator)             (Sixth Sense)                 0.7
# 2              (Sixth Sense)                 (Patriot)                 0.6
# 3                  (Patriot)             (Sixth Sense)                 0.6
# 4               (Green Mile)             (Sixth Sense)                 0.2
# 5                  (Patriot)               (Gladiator)                 0.6
# 6                (Gladiator)                 (Patriot)                 0.7
# ...

# %% [markdown]
# B. alpha 0.7, min support = 0.3, min confidence = 0.6, min length = 1

# %%
def generate_rules(movies_data, min_support, min_confidence, min_length):
    
    items_freq = apriori(movies_data, min_support=min_support, use_colnames=True)
    
    # Generate association rules
    rules = association_rules(items_freq, metric="confidence", min_threshold=min_confidence)
    
    # Filter rules based on minimum length
    rules = rules[rules['antecedents'].apply(lambda x: len(x)) >= min_length]
    
    # Plotting
    plt.figure(figsize=(10, 5)) 
    plt.scatter(rules['support'], rules['confidence'], alpha=0.7)
    plt.xlabel('Support')
    plt.ylabel('Confidence')
    plt.title('Association Rules:')
    plt.show()
    
    return rules 

# Set the minimum support, confidence, and length
min_support = 0.3
min_confidence = 0.6
min_length = 1

# Generate rules
rules = generate_rules(movies_data.iloc[:, 5:], min_support, min_confidence, min_length)

# Display the rules
print("Rules of Association for movies data:")
print(rules)
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Rules of Association for movies data:
#                  antecedents               consequents  antecedent support  \
# 0              (Sixth Sense)               (Gladiator)                 0.6
# 1                (Gladiator)             (Sixth Sense)                 0.7
# 2              (Sixth Sense)                 (Patriot)                 0.6
# 3                  (Patriot)             (Sixth Sense)                 0.6
# 4                (Gladiator)                 (Patriot)                 0.7
# 5                  (Patriot)               (Gladiator)                 0.6
# 6   (Sixth Sense, Gladiator)                 (Patriot)                 0.5
# ...

# %% [markdown]
# C. alpha = 0.4, min support = 0.25, min confidence = 0.7, min length = 1

# %%
def generate_rules(movies_data, min_support, min_confidence, min_length):
    
    items_freq = apriori(movies_data, min_support=min_support, use_colnames=True)
    
    # Generate association rules
    rules = association_rules(items_freq, metric="confidence", min_threshold=min_confidence)
    
    # Filter rules based on minimum length
    rules = rules[rules['antecedents'].apply(lambda x: len(x)) >= min_length]
    
    # Plotting
    plt.figure(figsize=(10, 5)) 
    plt.scatter(rules['support'], rules['confidence'], alpha=0.4)
    plt.xlabel('Support')
    plt.ylabel('Confidence')
    plt.title('Association Rules:')
    plt.show()
    
    return rules 

# Set the minimum support, confidence, and length
min_support = 0.25
min_confidence = 0.7
min_length = 1

# Generate rules
rules = generate_rules(movies_data.iloc[:, 5:], min_support, min_confidence, min_length)

# Display the rules
print("Rules of Association for movies data:")
print(rules)
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Rules of Association for movies data:
#                 antecedents    consequents  antecedent support  \
# 0             (Sixth Sense)    (Gladiator)                 0.6
# 1               (Gladiator)  (Sixth Sense)                 0.7
# 2                 (Patriot)    (Gladiator)                 0.6
# 3               (Gladiator)      (Patriot)                 0.7
# 4    (Sixth Sense, Patriot)    (Gladiator)                 0.4
# 5  (Sixth Sense, Gladiator)      (Patriot)                 0.5
#
#    consequent support  support  confidence      lift  leverage  conviction  \
# 0                 0.7      0.5    0.833333  1.190476      0.08         1.8
# ...

# %% [markdown]
# ### II. Books

# %%
books_data = pd.read_csv('book.csv')

# %% [markdown]
# A. alpha 0.5, min support = 0.2, min confidence = 0.6, min length = 0.5

# %%
def generate_rules(books_data, min_support, min_confidence, min_length):
    
    items_freq2 = apriori(books_data, min_support=min_support, use_colnames=True)
    
    # rules
    rules = association_rules(items_freq2, metric="confidence", min_threshold=min_confidence)
    rules = rules[rules['antecedents'].apply(lambda x: len(x)) >= min_length]
    
    #Plotting og books data
    plt.figure(figsize=(10,7))
    plt.scatter(rules['support'], rules['confidence'], alpha=0.5)
    plt.xlabel('Support')
    plt.ylabel('Confidence')
    plt.title('Asso rules of Books data:')
    plt.show()
    
    return rules 


min_support = 0.2
min_confidence = 0.6 
min_length = 0.5 

rules = generate_rules(books_data.iloc[:,:], min_support, min_confidence, min_length) 
print("Rules of Asso of Books data")

print(rules)
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Rules of Asso of Books data
#   antecedents consequents  antecedent support  consequent support  support  \
# 0  (ChildBks)   (CookBks)               0.423               0.431    0.256
#
#    confidence      lift  leverage  conviction  zhangs_metric
# 0    0.605201  1.404179  0.073687     1.44124       0.498856

# %% [markdown]
# B. alpha 0.7, min support = 0.1, min confidence = 0.4, min length = 0.2

# %%
def generate_rules(books_data, min_support, min_confidence, min_length):
    
    items_freq2 = apriori(books_data, min_support=min_support, use_colnames=True)
    
    # rules
    rules = association_rules(items_freq2, metric="confidence", min_threshold=min_confidence)
    rules = rules[rules['antecedents'].apply(lambda x: len(x)) >= min_length]
    
    #Plotting og books data
    plt.figure(figsize=(10,7))
    plt.scatter(rules['support'], rules['confidence'], alpha=0.7)
    plt.xlabel('Support')
    plt.ylabel('Confidence')
    plt.title('Asso rules of Books data:')
    plt.show()
    
    return rules 


min_support = 0.1
min_confidence = 0.4
min_length = 0.2

rules = generate_rules(books_data.iloc[:,:], min_support, min_confidence, min_length) 
print("Rules of Asso of Books data")

print(rules)
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Rules of Asso of Books data
#             antecedents         consequents  antecedent support  \
# 0            (YouthBks)          (ChildBks)              0.2475
# 1             (CookBks)          (ChildBks)              0.4310
# 2            (ChildBks)           (CookBks)              0.4230
# 3            (ChildBks)          (DoItYBks)              0.4230
# 4            (DoItYBks)          (ChildBks)              0.2820
# ..                  ...                 ...                 ...
# 65  (DoItYBks, GeogBks)           (CookBks)              0.1325
# 66   (CookBks, GeogBks)            (ArtBks)              0.1925
# ...

# %% [markdown]
# C. alpha 0.4, min support = 0.1, min confidence = 0.3, min length = 1

# %%
def generate_rules(books_data, min_support, min_confidence, min_length):
    
    items_freq2 = apriori(books_data, min_support=min_support, use_colnames=True)
    
    # rules
    rules = association_rules(items_freq2, metric="confidence", min_threshold=min_confidence)
    rules = rules[rules['antecedents'].apply(lambda x: len(x)) >= min_length]
    
    #Plotting og books data
    plt.figure(figsize=(10,7))
    plt.scatter(rules['support'], rules['confidence'], alpha=0.4)
    plt.xlabel('Support')
    plt.ylabel('Confidence')
    plt.title('Asso rules of Books data:')
    plt.show()
    
    return rules 


min_support = 0.1
min_confidence = 0.3
min_length = 1

rules = generate_rules(books_data.iloc[:,:], min_support, min_confidence, min_length) 
print("Rules of Asso of Books data")

print(rules)
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Rules of Asso of Books data
#            antecedents         consequents  antecedent support  \
# 0           (ChildBks)          (YouthBks)              0.4230
# 1           (YouthBks)          (ChildBks)              0.2475
# 2            (CookBks)          (ChildBks)              0.4310
# 3           (ChildBks)           (CookBks)              0.4230
# 4           (ChildBks)          (DoItYBks)              0.4230
# ..                 ...                 ...                 ...
# 84  (CookBks, GeogBks)            (ArtBks)              0.1925
# 85   (CookBks, ArtBks)           (GeogBks)              0.1670
# ...
